# %%
import pandas as pd
import numpy as np
import os
import glob
import graphic_visualization.plot_graphics as GRAPH_VIS
import metrics.metrics as PRINT_METRICS
import model.models as MODELS

# %%
def get_path_training():
    path_train = os.getcwd()+"/" + \
        os.listdir()[int([i for i in range(len(os.listdir()))
                          if os.listdir()[i] == 'data'][0])]
    path_train_final = path_train+"/"+os.listdir(path_train)[int([i for i in range(
        len(os.listdir(path_train))) if os.listdir(path_train)[i] == 't1d'][0])]+"/"
    return (path_train_final)

# %%
data_ = ""

# %%
print("update")
# Out:
# update

# %%
# for file_name in glob.glob(get_path_training()+'*.csv'):
#     data_cleber = pd.read_csv(file_name, index_col=0)
#     data_cleber.drop(['gl_predict'], axis=1, inplace=True)
#     print(data_cleber.head())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 for file_name in glob.glob(get_path_training()+'*.csv'):
#       2     data_cleber = pd.read_csv(file_name, index_col=0)
#       3     data_cleber.drop(['gl_predict'], axis=1, inplace=True)
#
# Cell In[3], line 3, in get_path_training()
#       1 def get_path_training():
#       2     path_train = os.getcwd()+"/" + \
# ----> 3         os.listdir()[int([i for i in range(len(os.listdir()))
#       4                           if os.listdir()[i] == 'data'][0])]
#       5     path_train_final = path_train+"/"+os.listdir(path_train)[int([i for i in range(
#       6         len(os.listdir(path_train))) if os.listdir(path_train)[i] == 't1d'][0])]+"/"
#       7     return (path_train_final)
#
# IndexError: list index out of range

# %%
# GRAPH_VIS.plot_graph(data_cleber, "t1d glucose")
# Out:
# plot graph
